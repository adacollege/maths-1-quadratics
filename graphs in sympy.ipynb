# %%
from sympy import *
x = Symbol('x')
init_printing()
import random
from IPython.display import display

# %%
a = plot(x**3-x,xlim=(-2,2),ylim=(-5,5),title=display(x**3-x))
# Out:
#  3
# x  - x

# %%
b = plot(x**3+x,xlim=(-2,2),ylim=(-5,5),title=display(x**3+x))
# Out:
#  3
# x  + x

# %%
c = plot(x**7+1,xlim=(-2,2),ylim=(-5,5),title=display(x**7+1))
# Out:
#  7
# x  + 1

# %%
d = plot(x**8-10*x**5+2*x+1,xlim=(-2,2),ylim=(-5,5))
